# %%
import os
import torch

# 1. Check if the GPU is available on the free tier
has_gpu = torch.cuda.is_available()
gpu_name = torch.cuda.get_device_name(0) if has_gpu else "None"

# 2. Check if your files are visible to Colab
files = os.listdir('.')
has_pipeline = "pipeline.py" in files

print(f"📡 Extension Status: {'✅ READY' if has_pipeline else '❌ FILES NOT SYNCED'}")
print(f"🎮 GPU Status: {'✅ ' + gpu_name if has_gpu else '❌ FREE QUOTA EXHAUSTED'}")
print(f"📂 Files found in Colab: {files}")

if not has_pipeline:
    print("\n💡 Tip: You might need to use the 'Google Colab: Sync Workspace' command or upload your files manually to the Colab sidebar.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 import torch
#       3
#       4 # 1. Check if the GPU is available on the free tier
#       5 has_gpu = torch.cuda.is_available()
#
# ModuleNotFoundError: No module named 'torch'
